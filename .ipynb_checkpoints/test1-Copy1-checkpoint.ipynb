# %%
import torch
import torch.optim as optim
import torch.nn as nn
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

torch.manual_seed(42)
p = torch.tensor([10,8,6,4,2],dtype=torch.float)
p1=torch.diag(p)
n=5
tao=100
dt = 1e-3
T=int(10/dt)
B=10
w=torch.randn(n,n, device='cpu', requires_grad=True,dtype=torch.float)
w1=torch.diag(w)
w_rec=torch.diag(w1)
w1_rec = w-w_rec
lr = 1e-3
n_epochs = 1000
optimizer = optim.Adam([w], lr=lr)
V=torch.zeros(T,n)
ep=np.arange(n_epochs)
Loss=torch.zeros(n_epochs,)
for epoch in range(n_epochs):
    z=torch.randn(1,n)
    Z=torch.zeros(T,n)
    for t in range(T):
        N=torch.randn(1,n)
        z_dot=(-z+(z@w1_rec)/math.sqrt(n))
        z = z + z_dot*dt+N*math.sqrt(dt)
        Z[t] = z
    

    loss = ((Z@p1)**2).mean()
    
    loss.backward()       
    optimizer.step()
    optimizer.zero_grad()
    Loss[epoch]=loss
 
plt.plot(ep,Loss.detach().numpy())
plt.show()


plt.plot(Z[:,0].detach().numpy(), Z[:,1].detach().numpy())
plt.show()  



color=['b','c','k','g','w','m','r','y']
for a in range(8):
    z=torch.randn(1,n)
    Z=torch.zeros(int(T/2),n)
    for t in range(T):
        N=torch.randn(1,n)
        z_dot=(-z+(z@w1_rec)/math.sqrt(n))
        z = z + z_dot*dt+N*math.sqrt(dt)
        q= int(t-T/2)
        Z[q] = z
  
    V=torch.zeros(n,1)

    for i in range(n):
        V[i]=torch.var(Z[:,i])
    print (V)
    
    plt.scatter(p,V.detach().numpy(),color=color[a])
    


                
plt.show()  



    
    
#plt.plot(p,V.detach().numpy(), 'r--', p, V2.detach().numpy(), 'bs', p, V.detach().numpy(), 'g^')
#plt.show()
# Out:
# tensor([[0.6411],
#         [1.2850],
#         [0.3494],
#         [0.4903],
#         [0.3138]], grad_fn=<CopySlices>)
# tensor([[0.4602],
#         [0.8769],
#         [0.3169],
#         [0.4566],
#         [0.3847]], grad_fn=<CopySlices>)
# tensor([[0.2013],
#         [0.6409],
#         [1.0128],
#         [0.4452],
#         [0.8380]], grad_fn=<CopySlices>)
# tensor([[0.2739],
#         [0.8852],
#         [0.1935],
#         [1.0201],
#         [0.2418]], grad_fn=<CopySlices>)
# tensor([[0.2777],
#         [0.6781],
#         [0.3196],
#         [0.1064],
#         [0.2803]], grad_fn=<CopySlices>)
# tensor([[0.1567],
#         [0.4308],
#         [0.2850],
#         [0.1128],
#         [0.1718]], grad_fn=<CopySlices>)
# tensor([[0.3661],
#         [0.2393],
#         [0.1221],
#         [0.4269],
#         [0.5155]], grad_fn=<CopySlices>)
# tensor([[0.2625],
#         [1.0788],
#         [0.2406],
#         [0.6164],
#         [0.3638]], grad_fn=<CopySlices>)

# %%
import pandas as pd

df=pd.DataFrame(Loss.detach().numpy())
rolling_mean = df.rolling(window=30).mean()
plt.plot(ep, rolling_mean, label='Learning Curve', color='k')

# %%
import pandas as pd

num_samples = 10
num_classes = 9


df = pd.DataFrame(index=range(num_samples), columns=[str(x) for x in range(num_classes)])


for i in range(num_samples):
    df.iloc[i] = torch.randn(1, num_classes).numpy().round(2)
    
    
dataset = pd.DataFrame({'Column1':data[:,0],'Column2':data[:,1]})


rolling_mean = df.rolling(window=20).mean()

plt.plot(ep, rolling_mean, label='', color='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-974c9055cf93> in <module>
#       5
#       6
# ----> 7 rolling_mean = Loss.detach().numpy().rolling(window=20).mean()
#       8 plt.plot(df.ds, rolling_mean, label='AMD 20 Day SMA', color='orange')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'rolling'

# %%
print (w1_rec)
# Out:
# tensor([[ 0.0000,  0.1288,  0.2345],
#         [ 0.2303,  0.0000, -0.1863],
#         [ 2.2082, -0.6380,  0.0000]], grad_fn=<SubBackward0>)

# %%
import matplotlib.pyplot as plt

print(torch.var(Z[:,0]),torch.var(Z[:,1]),torch.var(Z[:,2]))



V=torch.zeros(3,1)

for i in range(3):
            V[i]=torch.var(Z[:,i])

print (V)
            

plt.scatter(p,V.detach().numpy(), marker='o')
plt.show
# Out:
# tensor(8.0256e-05, grad_fn=<VarBackward0>) tensor(9.7562e-05, grad_fn=<VarBackward0>) tensor(8.7471e-05, grad_fn=<VarBackward0>)
# tensor([[8.0256e-05],
#         [9.7562e-05],
#         [8.7471e-05]], grad_fn=<CopySlices>)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(A[:,0].detach().numpy(), A[:,1].detach().numpy())



plt.show()

# %%
import numpy 
import torch
import math

import matplotlib.pyplot as plt
import pandas as pd

n=3
tao=100
T=1000
dt = 0.01
B=10
w=torch.randn(n,n, device='cpu', requires_grad=True)
w1=torch.diag(w)
w_rec=torch.diag(w1)
z=torch.randn(1,n)

Z=torch.zeros(T,n)


for t in range(T):
    N=torch.randn(1,n)
    z_dot=(-z+z@w_rec)/tao+N*math.sqrt(dt)
    z = z + z_dot*dt
    #print (z)
    Z[t] = z
    
   
    
    



#print (Z[:,0].detach().numpy(), Z[:,1].detach().numpy())

plt.plot(Z[:,0].detach().numpy(), Z[:,1].detach().numpy())

plt.show()

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import numpy 
import math
import matplotlib.pyplot as plt
import pandas as pd





torch.manual_seed(42)

n=3
tao=100
T=1000
dt = 0.01
B=10
w=torch.randn(n,n, device='cpu', requires_grad=True)
w1=torch.diag(w)
w_rec=torch.diag(w1)
w1_rec = w-w_rec



lr = 1e-3
n_epochs = 1000



optimizer = optim.Adam([w], lr=lr)
Z=torch.zeros(n_epochs,n)

for epoch in range(n_epochs):
    z=torch.randn(1,n)
    


    for t in range(T):
        N=torch.randn(1,n)
        z_dot=(-z+z@w1_rec)/tao+N*math.sqrt(dt)
        z = z + z_dot*dt
        
      
    loss = (z**2.mean()

    loss.backward()       
    optimizer.step()
    optimizer.zero_grad()
    Z[epoch] = z
    

print (Z)
print (w1_rec)
plt.plot(Z[:,0].detach().numpy(), Z[:,1].detach().numpy())

plt.show()

# %%
print
